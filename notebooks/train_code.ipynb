# %%
# !git clone https://github.com/AmirMishael/Mario_IDM_DL.git
# %cd ./Mario_IDM_DL
# !chmod 777 ./download_data.bash
# !./download_data.bash
# Out:
# Cloning into 'Mario_IDM_DL'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 26 (delta 4), reused 13 (delta 0), pack-reused 0
# Unpacking objects: 100% (26/26), 5.50 KiB | 1.10 MiB/s, done.
# /content/Mario_IDM_DL
# --2023-06-02 13:48:44--  https://github.com/rafaelcp/smbdataset/raw/main/data-smb.7z
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/rafaelcp/smbdataset/main/data-smb.7z [following]
# --2023-06-02 13:48:44--  https://media.githubusercontent.com/media/rafaelcp/smbdataset/main/data-smb.7z
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %%
# !./download_data.bash
# Out:
# --2023-06-02 13:51:04--  https://github.com/rafaelcp/smbdataset/raw/main/data-smb.7z
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/rafaelcp/smbdataset/main/data-smb.7z [following]
# --2023-06-02 13:51:04--  https://media.githubusercontent.com/media/rafaelcp/smbdataset/main/data-smb.7z
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to media.githubusercontent.com (media.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 932651968 (889M) [application/octet-stream]
# Saving to: ‘./tmp_download/data-smb.7z’
#
# ./tmp_download/data 100%[===================>] 889.45M   275MB/s    in 3.2s
#
# ...
